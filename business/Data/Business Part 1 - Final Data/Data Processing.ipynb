# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/wangyunong/Desktop/group6/Businesses/whole/London_businesses.csv')
# Out:
# /Users/wangyunong/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    Unnamed: 0 CompanyNumber  \
# 0     1084783        683517
# 1      227841       5712940
# 2      994313       5951784
# 3      971134       6860548
# 4      423404       5464088
#
#                              RegAddress.AddressLine1 RegAddress.AddressLine2  \
# 0                                     8 BAKER STREET                  LONDON
# 1                                           GRIFFINS   TAVISTOCK HOUSE SOUTH
# 2  C/O HARRISONS BUSINESS RECOVERY & INSOLVENCY (...               4TH FLOOR
# 3               CVR GLOBAL LLP NEW FETTER PLACE WEST          55 FETTER LANE
# 4                              1417-1419 LONDON ROAD                 NORBURY
#
#   RegAddress.PostTown RegAddress.PostCode                  SICCode.SicText_1  \
# 0                 NaN              W1M1DA  0111 - Grow cereals & other crops
# 1              LONDON             WC1H9LG  0111 - Grow cereals & other crops
# 2              LONDON              W1D7EQ  0111 - Grow cereals & other crops
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# CompanyNumber               object
# RegAddress.AddressLine1     object
# RegAddress.AddressLine2     object
# RegAddress.PostTown         object
# RegAddress.PostCode         object
# SICCode.SicText_1           object
# pcds                        object
# oa11                        object
# laua                        object
# ward                        object
# lsoa11                      object
# msoa11                      object
# wz11                        object
# lat                        float64
# long                       float64
# SIC                          int64
# twoDigit                     int64
# dtype: object

# %%
pd.set_option('display.max_rows',None)

# %%
df.ward.value_counts()
# Out:
# E05000649    44171
# E05000138    44131
# E05009378    36808
# E05000367    30254
# E05000644    21607
# E05009305    20951
# E05009292    18068
# E05000641    16912
# E05000061    10860
# E05000129     9642
# E05000288     9029
# E05009323     8188
# E05009377     7913
# E05000153     7392
# E05000370     7147
# E05000632     7045
# E05000051     6711
# E05000613     5889
# E05000536     5503
# E05000141     5244
# E05009304     5235
# E05000491     5063
# E05009310     4611
# E05009309     4594
# E05000492     4572
# E05000054     4499
# E05009336     4334
# E05000142     4318
# E05000208     4209
# E05000045     4206
# E05009318     4142
# E05000056     4126
# E05009333     4103
# E05000213     3805
# E05000548     3709
# E05000133     3587
# E05000102     3443
# E05000636     3421
# E05000500     3333
# E05000514     3212
# E05000175     3172
# E05000050     3164
# E05000286     3157
# E05009401     3129
# E05000130     3105
# E05000205     3092
# E05000365     3088
# ...

# %%
Agriculture = df.loc[(df['SIC']== 28301) | (df['SIC']== 28302) | (df['SIC']== 46110) 
                     | (df['SIC']== 46610) | (df['SIC']== 64201) | (df['SIC']== 77310)
                     | (df['SIC']== 2100) | (df['SIC']== 2400) | (df['SIC']== 28302) 
                     | (df['SIC']== 3110) | (df['SIC']== 3120) | (df['SIC']== 10200) | (df['SIC']== 46380) | (df['SIC']== 47230) | (df['SIC']== 47640) ]

# %%
Agriculture.to_csv("Agriculture.csv")

# %%
Agriculture.ward.value_counts()
# Out:
# E05000649    158
# E05000138    137
# E05009378    105
# E05000367     99
# E05009323     38
# E05009305     36
# E05000129     28
# E05000061     24
# E05000641     21
# E05000644     20
# E05009292     19
# E05000288     16
# E05000153     15
# E05009377     14
# E05000536     14
# E05000603     13
# E05000343     13
# E05000542     13
# E05000175     13
# E05000039     12
# E05000513     12
# E05009336     11
# E05000625     11
# E05000100     11
# E05000058     10
# E05009333     10
# E05000051     10
# E05000056     10
# E05000484      9
# E05000564      9
# E05000500      9
# E05000319      9
# E05000276      9
# E05000370      9
# E05000045      8
# E05000062      8
# E05000545      8
# E05000230      8
# E05000208      8
# E05000055      8
# E05000492      8
# E05000336      8
# E05000213      8
# E05000616      7
# E05000179      7
# E05000050      7
# E05009310      7
# E05000455      7
# E05000191      7
# E05000488      7
# E05000632      7
# E05009318      7
# ...

# %%
Mining = df.loc[(df['SIC']== 5200) | (df['SIC']== 7100) | (df['SIC']== 7210) 
| (df['SIC']== 7290) | (df['SIC']== 8120) | (df['SIC']== 8910) | (df['SIC']== 8990) | (df['SIC']== 9900) | (df['SIC']== 28921) | (df['SIC']== 46630)]

# %%
Mining.to_csv("Mining.csv")

# %%
Mining.ward.value_counts()
# Out:
# E05000649    104
# E05000644     62
# E05009292     57
# E05000138     55
# E05000367     51
# E05009378     36
# E05009305     35
# E05000129     26
# E05009309     22
# E05000641     19
# E05000632     10
# E05000548      9
# E05000061      9
# E05000536      9
# E05009288      8
# E05000622      7
# E05009304      7
# E05000370      7
# E05000647      7
# E05009393      6
# E05009323      6
# E05000542      5
# E05009318      5
# E05000408      5
# E05000341      4
# E05000141      4
# E05000365      4
# E05000142      4
# E05000492      4
# E05009377      4
# E05000459      4
# E05009330      4
# E05000128      4
# E05000637      4
# E05000419      4
# E05009400      4
# E05000102      4
# E05000625      4
# E05000288      4
# E05000491      4
# E05000164      3
# E05000406      3
# E05009332      3
# E05000553      3
# E05000132      3
# E05000175      3
# E05000284      3
# E05000254      3
# E05009388      3
# E05000085      3
# E05000252      3
# E05000646      3
# ...

# %%
Construction = df.loc[(df['SIC']== 23320) | (df['SIC']== 23610) | (df['SIC']== 23620) 
| (df['SIC']== 41201) | (df['SIC']== 41202) | (df['SIC']== 42110) | (df['SIC']== 42120) | (df['SIC']== 42130) | (df['SIC']== 42210) | (df['SIC']== 42220) | (df['SIC']== 42910) | (df['SIC']== 42990) | (df['SIC']== 43290) | (df['SIC']== 43999) | (df['SIC']== 46630) | (df['SIC']== 46730) | (df['SIC']== 64203) | (df['SIC']== 77320)]

# %%
Construction.to_csv('Construction.csv')

# %%
Construction.ward.value_counts()
# Out:
# E05009378    732
# E05000138    686
# E05000367    617
# E05000649    449
# E05000061    296
# E05000288    263
# E05000083    236
# E05000173    190
# E05009292    187
# E05000492    185
# E05009403    181
# E05000319    178
# E05000053    176
# E05009323    176
# E05000153    173
# E05000644    168
# E05000608    165
# E05000099    160
# E05000641    159
# E05000500    156
# E05000056    155
# E05000482    154
# E05000051    153
# E05000102    145
# E05000141    145
# E05000205    144
# E05000365    144
# E05000506    143
# E05000514    143
# E05009305    142
# E05000341    140
# E05000109    139
# E05000496    139
# E05000343    137
# E05000054    135
# E05000471    134
# E05000113    132
# E05000213    132
# E05000499    129
# E05000230    125
# E05000050    124
# E05000512    123
# E05000039    122
# E05000187    122
# E05000208    122
# E05000046    121
# E05000285    120
# E05000026    117
# E05000632    117
# E05000475    117
# E05000097    117
# E05000287    116
# ...

# %%
Manufacture = df.loc[(df['SIC']== 26512) | (df['SIC']== 26513) | (df['SIC']== 26514) | (df['SIC']== 26520) | (df['SIC']== 26600) 
| (df['SIC']== 26701) | (df['SIC']== 26702) | (df['SIC']== 26800) | (df['SIC']== 27110) | (df['SIC']== 27120) | (df['SIC']== 27200) | (df['SIC']== 27310) | (df['SIC']== 27320) | (df['SIC']== 27330) | (df['SIC']== 27400) | (df['SIC']== 27510) | (df['SIC']== 27520) | (df['SIC']== 27900) | (df['SIC']== 28110) | (df['SIC']== 28120) | (df['SIC']== 28131) | (df['SIC']== 28132) 
| (df['SIC']== 28140) | (df['SIC']== 28150) | (df['SIC']== 28210) | (df['SIC']== 28220) | (df['SIC']== 28230) | (df['SIC']== 28240) | (df['SIC']== 28250) | (df['SIC']== 28290) | (df['SIC']== 28301) | (df['SIC']== 28302) | (df['SIC']== 28410) | (df['SIC']== 28490) | (df['SIC']== 28910) | (df['SIC']== 28921) | (df['SIC']== 28922) | (df['SIC']== 28923) | (df['SIC']== 28930) 
| (df['SIC']== 28940) | (df['SIC']== 28950) | (df['SIC']== 28960) | (df['SIC']== 28990) | (df['SIC']== 29100) | (df['SIC']== 29201) | (df['SIC']== 29202) | (df['SIC']== 29203) | (df['SIC']== 29310) | (df['SIC']== 29320) | (df['SIC']== 30200) | (df['SIC']== 30300) | (df['SIC']== 30400) | (df['SIC']== 30910) | (df['SIC']== 30920) | (df['SIC']== 30990) | (df['SIC']== 31010) 
| (df['SIC']== 31020) | (df['SIC']== 31030) | (df['SIC']== 31090) | (df['SIC']== 32120) | (df['SIC']== 32130) | (df['SIC']== 32200) | (df['SIC']== 32300) | (df['SIC']== 32401) | (df['SIC']== 32409) | (df['SIC']== 32500) | (df['SIC']== 32910) | (df['SIC']== 32990) | (df['SIC']== 35210) | (df['SIC']== 46210)]

# %%
Manufacture.to_csv('Manufacture.csv')

# %%
Manufacture.ward.value_counts()
# Out:
# E05000138    564
# E05000649    409
# E05009378    307
# E05000367    255
# E05000644    130
# E05009305    118
# E05000641    107
# E05000054     96
# E05009292     93
# E05000061     85
# E05000129     61
# E05009377     61
# E05009304     60
# E05000370     58
# E05000536     53
# E05009309     48
# E05000288     46
# E05000051     46
# E05000548     46
# E05000632     45
# E05000175     43
# E05000056     38
# E05000141     34
# E05000153     33
# E05009323     33
# E05000173     32
# E05009336     32
# E05000341     32
# E05000213     30
# E05000303     29
# E05000045     29
# E05000455     29
# E05000102     28
# E05000325     28
# E05009318     27
# E05000205     27
# E05000100     26
# E05000208     26
# E05000603     25
# E05009401     25
# E05000063     24
# E05000280     23
# E05000142     23
# E05000365     22
# E05000159     22
# E05000637     22
# E05000152     22
# E05009333     22
# E05000319     22
# E05000149     21
# E05000542     21
# E05000459     21
# ...

# %%
Wholesale = df.loc[(df['SIC']== 45310)|(df['SIC']== 46210)|(df['SIC']== 46220)|(df['SIC']== 46230)|(df['SIC']== 46240)|(df['SIC']== 46310)|(df['SIC']== 46320)|(df['SIC']== 46330)|(df['SIC']== 46341)|(df['SIC']== 46342)|(df['SIC']== 46350)|(df['SIC']== 46360)|(df['SIC']== 46370)|(df['SIC']== 46380)|(df['SIC']== 46390)|(df['SIC']== 46410)|(df['SIC']== 46420)|(df['SIC']== 46431)|(df['SIC']== 46439)|(df['SIC']== 46440)|(df['SIC']== 46450)|(df['SIC']== 46460)|(df['SIC']== 46470)|(df['SIC']== 46480)|(df['SIC']== 46491)|(df['SIC']== 46499)|(df['SIC']== 46510)|(df['SIC']== 46520)|(df['SIC']== 46610)|(df['SIC']== 46620)|(df['SIC']== 46630)|(df['SIC']== 46640)|(df['SIC']== 46650)|(df['SIC']== 46660)|(df['SIC']== 46690)|(df['SIC']== 46711)|(df['SIC']== 46719)|(df['SIC']== 46720)|(df['SIC']== 46730)|(df['SIC']== 46740)|(df['SIC']== 46750)|(df['SIC']== 46760)|(df['SIC']== 46770)|(df['SIC']== 46900)]

# %%
Wholesale.to_csv('Wholesale.csv')

# %%
Wholesale.ward.value_counts()
# Out:
# E05000138    1526
# E05000649    1084
# E05000367     939
# E05009378     819
# E05009305     353
# E05000644     322
# E05000288     315
# E05000061     287
# E05000129     286
# E05009292     264
# E05000641     260
# E05000051     212
# E05009377     198
# E05000632     191
# E05009336     180
# E05000175     165
# E05000620     153
# E05009323     149
# E05009304     148
# E05000286     148
# E05009333     147
# E05000370     146
# E05000102     146
# E05000153     138
# E05000205     127
# E05000536     126
# E05000045     124
# E05000141     108
# E05000208     108
# E05000213     107
# E05000276     104
# E05000039     100
# E05000100      98
# E05000514      97
# E05000056      96
# E05000085      95
# E05009310      93
# E05000173      91
# E05000186      90
# E05000455      86
# E05000492      84
# E05000088      83
# E05000050      83
# E05000278      81
# E05000647      81
# E05000603      78
# E05000179      78
# E05000055      76
# E05000187      76
# E05000500      76
# ...

# %%
Retail = df.loc[(df['SIC']== 45320) | (df['SIC']== 47110) | (df['SIC']== 47190) 
| (df['SIC']== 47210) | (df['SIC']== 47220) | (df['SIC']== 47230) | (df['SIC']== 47240) | (df['SIC']== 47250) | (df['SIC']== 47260) | (df['SIC']== 47290) | (df['SIC']== 47300) | (df['SIC']== 47410) | (df['SIC']== 47421) | (df['SIC']== 47429) | (df['SIC']== 47430) | (df['SIC']== 47510) | (df['SIC']== 47520) | (df['SIC']== 47530) | (df['SIC']== 47540) | (df['SIC']== 47591) 
| (df['SIC']== 47599) | (df['SIC']== 47610) | (df['SIC']== 47620) | (df['SIC']== 47630) | (df['SIC']== 47640) | (df['SIC']== 47650) | (df['SIC']== 47710) | (df['SIC']== 47721) | (df['SIC']== 47722) | (df['SIC']== 47741) | (df['SIC']== 47749) | (df['SIC']== 47750) | (df['SIC']== 47760) | (df['SIC']== 47770) | (df['SIC']== 47781) | (df['SIC']== 47782) | (df['SIC']== 47789) | (df['SIC']== 47791) | (df['SIC']== 47799) | (df['SIC']== 47810) | (df['SIC']== 47820) | (df['SIC']== 47890) | (df['SIC']== 47910) | (df['SIC']== 47990)]

# %%
Retail.to_csv('Retail.csv')

# %%
Retail.ward.value_counts()
# Out:
# E05000138    2906
# E05000367    2029
# E05009378    1963
# E05000649    1556
# E05000153     647
# E05000061     544
# E05000644     488
# E05000641     445
# E05000288     434
# E05009305     395
# E05009377     384
# E05000632     297
# E05009333     289
# E05009336     280
# E05000051     262
# E05009292     260
# E05000129     255
# E05000339     243
# E05000370     234
# E05000102     229
# E05009304     217
# E05000189     213
# E05000491     207
# E05000468     205
# E05000514     203
# E05009323     200
# E05000213     199
# E05000130     197
# E05000045     194
# E05000056     190
# E05000286     179
# E05000050     177
# E05000208     176
# E05000230     174
# E05000501     171
# E05000205     170
# E05000492     166
# E05000490     164
# E05000278     163
# E05000141     160
# E05000536     160
# E05000486     159
# E05000175     159
# E05000485     156
# E05000350     155
# E05000062     154
# E05000500     152
# E05000502     151
# E05000173     151
# E05000197     150
# ...

# %%
Finance = df.loc[(df['SIC']== 64205) | (df['SIC']== 64910) | (df['SIC']== 64921) 
| (df['SIC']== 64922) | (df['SIC']== 64999) | (df['SIC']== 66110) | (df['SIC']== 66190) | (df['SIC']== 70221) | (df['SIC']== 70229) | (df['SIC']== 64301) | (df['SIC']== 64304) | (df['SIC']== 64306) | (df['SIC']== 65110) | (df['SIC']== 65120) | (df['SIC']== 65201) | (df['SIC']== 65202) | (df['SIC']== 66220) | (df['SIC']== 66290) | (df['SIC']== 64302) | (df['SIC']== 64305) 
| (df['SIC']== 65300) | (df['SIC']== 66300) | (df['SIC']== 64110) | (df['SIC']== 64191) | (df['SIC']== 68100) | (df['SIC']== 68201) | (df['SIC']== 68209) | (df['SIC']== 68310) | (df['SIC']== 68320)]

# %%
Finance.to_csv('Finance.csv')

# %%
Finance.ward.value_counts()
# Out:
# E05000649    8962
# E05000138    6740
# E05009292    5550
# E05000644    4531
# E05000367    4510
# E05009378    3901
# E05000641    3366
# E05009305    2288
# E05000061    1929
# E05009323    1797
# E05000051    1746
# E05009310    1650
# E05000288    1622
# E05000632    1508
# E05000613    1234
# E05009377    1191
# E05000052    1181
# E05009383    1154
# E05000370    1129
# E05000278    1122
# E05000129    1044
# E05000520    1030
# E05009309    1027
# E05000153     990
# E05009304     953
# E05000053     913
# E05000636     899
# E05000045     887
# E05000536     837
# E05000208     822
# E05009318     778
# E05000056     757
# E05000141     752
# E05009368     684
# E05000213     683
# E05009336     681
# E05000286     676
# E05000133     666
# E05000055     663
# E05000647     655
# E05000548     653
# E05009403     630
# E05009333     626
# E05000050     602
# E05000537     587
# E05009389     575
# E05000102     563
# E05000109     561
# E05000637     535
# E05009302     532
# ...

# %%
Services = df.loc[(df['SIC']== 2400) | (df['SIC']== 18130) | (df['SIC']== 18140) 
| (df['SIC']== 39000) | (df['SIC']== 49420) | (df['SIC']== 56290) | (df['SIC']== 64205) | (df['SIC']== 73120) | (df['SIC']== 81221) | (df['SIC']== 81222) | (df['SIC']== 81223) | (df['SIC']== 81291) | (df['SIC']== 81299) | (df['SIC']== 84120) | (df['SIC']== 85600)]

# %%
Services.to_csv('Services.csv')

# %%
Services.ward.value_counts()
# Out:
# E05000649    835
# E05000138    788
# E05009378    633
# E05000367    615
# E05009292    387
# E05000644    364
# E05009305    275
# E05009377    187
# E05000641    177
# E05000061    161
# E05009333    154
# E05000288    142
# E05009323    135
# E05000632    125
# E05009310    122
# E05000129    113
# E05000536    105
# E05000153    104
# E05000492    102
# E05009309     98
# E05009304     95
# E05000370     93
# E05000542     93
# E05009336     92
# E05009302     80
# E05000141     75
# E05000420     75
# E05000175     74
# E05000051     74
# E05000205     73
# E05000256     71
# E05000637     70
# E05000168     67
# E05000026     67
# E05000045     67
# E05000208     65
# E05000142     64
# E05000514     63
# E05000253     61
# E05000319     61
# E05000491     59
# E05000055     59
# E05000102     58
# E05000371     58
# E05000130     57
# E05000062     57
# E05000548     57
# E05000622     57
# E05009318     57
# E05000059     56
# E05000056     56
# E05000626     56
# ...

# %%
Wholesale.laua.value_counts()
# Out:
# E09000007    2398
# E09000033    2317
# E09000003    1609
# E09000019    1363
# E09000012    1325
# E09000015    1127
# E09000009    1063
# E09000005    1026
# E09000001     985
# E09000030     904
# E09000010     903
# E09000026     851
# E09000025     762
# E09000017     728
# E09000008     697
# E09000018     645
# E09000014     581
# E09000032     571
# E09000028     534
# E09000031     520
# E09000024     483
# E09000020     452
# E09000013     447
# E09000002     374
# E09000022     372
# E09000006     339
# E09000016     290
# E09000011     287
# E09000029     284
# E09000027     281
# E09000004     259
# E09000021     254
# E09000023     249
# Name: laua, dtype: int64
