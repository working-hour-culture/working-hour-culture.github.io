# %% [markdown]
# # Foursquare Data Preprocessing

# %%
import pandas as pd
pd.options.display.max_columns = 999
import numpy as np
import geopandas as gpd
import zipfile 
import shapely
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
poi.columns = ['venue_id', 'lat', 'lon', 'venue_type', 'country_code']
df.columns = ['user_id', 'venue_id', 'datetime', 'timezone']

# %%
df.merge(poi, on='venue_id').to_csv("poi.csv", header=True, index=False)

# %%
df = pd.read_csv("Foursquare_Data/check_ins.csv")

# %%
df = df.loc[df['venue_type']=='Office']
# Out:
#           user_id                  venue_id                        datetime  \
# 3069        66981  4b4606f2f964a520751426e3  Tue Apr 03 18:00:08 +0000 2012
# 3070        66981  4b4606f2f964a520751426e3  Wed Apr 04 19:20:35 +0000 2012
# 3071        66981  4b4606f2f964a520751426e3  Mon Apr 09 13:57:42 +0000 2012
# 3072        66981  4b4606f2f964a520751426e3  Thu Apr 12 13:27:53 +0000 2012
# 3073        66981  4b4606f2f964a520751426e3  Fri Apr 13 15:41:49 +0000 2012
# 3074        66981  4b4606f2f964a520751426e3  Mon Apr 16 13:27:18 +0000 2012
# 3075        66981  4b4606f2f964a520751426e3  Tue Apr 17 13:35:50 +0000 2012
# 3076        66981  4b4606f2f964a520751426e3  Wed Apr 18 14:06:12 +0000 2012
# 3077        66981  4b4606f2f964a520751426e3  Thu Apr 19 14:19:50 +0000 2012
# 3078        66981  4b4606f2f964a520751426e3  Thu Apr 19 18:31:02 +0000 2012
# 3079        66981  4b4606f2f964a520751426e3  Fri Apr 20 16:20:29 +0000 2012
# ...
